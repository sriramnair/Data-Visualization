# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import seaborn as sns

# %%
data = pd.read_csv('Street_Tree_List.csv')
# Out:
# C:\Users\shnai\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (4,10) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
data['Zip Codes'].nunique
# Out:
# <bound method IndexOpsMixin.nunique of 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#            ...
# 195672        64
# 195673    29,490
# 195674    28,859
# 195675    28,852
# 195676    28,853
# Name: Zip Codes, Length: 195677, dtype: object>

# %%
data == np.nan
# Out:
#         TreeID  qLegalStatus  qSpecies  qAddress  SiteOrder  qSiteInfo  \
# 0        False         False     False     False      False      False
# 1        False         False     False     False      False      False
# 2        False         False     False     False      False      False
# 3        False         False     False     False      False      False
# 4        False         False     False     False      False      False
# ...        ...           ...       ...       ...        ...        ...
# 195672   False         False     False     False      False      False
# 195673   False         False     False     False      False      False
# 195674   False         False     False     False      False      False
# 195675   False         False     False     False      False      False
# 195676   False         False     False     False      False      False
#
#         PlantType  qCaretaker  qCareAssistant  PlantDate  ...  XCoord  YCoord  \
# ...

# %%
data
# Out:
#         TreeID    qLegalStatus  \
# 0        48142  Permitted Site
# 1        19725  DPW Maintained
# 2       121399  DPW Maintained
# 3        46536  Permitted Site
# 4       251210  DPW Maintained
# ...        ...             ...
# 195672     231  DPW Maintained
# 195673   92652  Permitted Site
# 195674  108942  Permitted Site
# 195675  143411  DPW Maintained
# 195676   15238  DPW Maintained
#
#                                                  qSpecies           qAddress  \
# 0                                              Tree(s) ::                NaN
# 1                                   Pinus Spp :: Pine Spp     100 STAIRWAY14
# 2                 Corymbia ficifolia :: Red Flowering Gum     349X Cargo Way
# 3                                              Tree(s) ::       73 Summer St
# 4       Eucalyptus polyanthemos :: Silver Dollar Eucal...    1170 Ingalls St
# ...                                                   ...                ...
# ...

# %%
data['qSiteInfo'].unique()
# Out:
# array(['Sidewalk: Curb side : Cutout', 'Side Yard : Yard',
#        'Back Yard : Yard', 'Sidewalk: Property side : Yard',
#        'Median : Yard', 'Unaccepted Street : Yard', 'Front Yard : Yard',
#        'Sidewalk: Curb side : Yard', 'Sidewalk: Property side : Cutout',
#        'Unaccepted Street : Cutout', 'Median : Cutout',
#        'Side Yard : Cutout', 'unknown : Yard', 'Back Yard : Cutout',
#        'Sidewalk: Curb side : Pot', 'Sidewalk: Curb side :', 'Median :',
#        ':', 'Front Yard : Pot', 'Front Yard : Cutout',
#        'Unaccepted Street : Pot', ': Yard', ': Cutout', 'Front Yard :',
#        'Sidewalk: Property side : Pot', 'Sidewalk: Property side :',
#        'unknown : Cutout', 'Hanging basket : Cutout',
#        'Sidewalk: Curb side : Hanging Pot', 'Hanging basket : Yard',
#        'unknown : Pot', 'Median : Hanging Pot'], dtype=object)

# %% [markdown]
# There are 195677 trees

# %%
data['qSiteInfo']
# Out:
# 0             Sidewalk: Curb side : Cutout
# 1             Sidewalk: Curb side : Cutout
# 2             Sidewalk: Curb side : Cutout
# 3             Sidewalk: Curb side : Cutout
# 4             Sidewalk: Curb side : Cutout
#                         ...
# 195672        Sidewalk: Curb side : Cutout
# 195673    Sidewalk: Property side : Cutout
# 195674        Sidewalk: Curb side : Cutout
# 195675        Sidewalk: Curb side : Cutout
# 195676        Sidewalk: Curb side : Cutout
# Name: qSiteInfo, Length: 195677, dtype: object

# %%
# !ls
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %%
i = 4
# Out:
# <function nt.listdir(path=None)>

# %%
data['Zip Codes'].dtypes
# Out:
# dtype('O')

# %%
plt.hist(data['Police Districts'])
# Out:
# (array([10575., 12163., 23075., 25892., 15752., 19998., 31459., 31094.,
#         21503.,  1029.]),
#  array([ 1. ,  1.9,  2.8,  3.7,  4.6,  5.5,  6.4,  7.3,  8.2,  9.1, 10. ]),
#  <BarContainer object of 10 artists>)

# %%
q = data[data['qCaretaker'] == 'Private']

# %%
r = data[data['qCaretaker'] == 'DPW']

# %%
plt.hist2d(x=q, y=r)
# Out:
# C:\Users\shnai\anaconda3\lib\site-packages\numpy\core\_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-89-f509ae60be08> in <module>
# ----> 1 plt.hist2d(x=q, y=r)
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in hist2d(x, y, bins, range, density, weights, cmin, cmax, data, **kwargs)
#    2696         x, y, bins=10, range=None, density=False, weights=None,
#    2697         cmin=None, cmax=None, *, data=None, **kwargs):
# -> 2698     __ret = gca().hist2d(
# ...
